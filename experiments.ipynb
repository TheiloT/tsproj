# %%
from cdlgr.outputs.metrics import average_multi_run_perfs

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # First set of experiments

# %%
def report_multi_run_results(experiment):
    dataset="synth"
    # TODO: add plots and time
    return average_multi_run_perfs(dataset, experiment, metric="accuracy")

# %% [markdown]
# ## Experiment 1

# %%
experiment = 1

# %%
# !ssrun dataset=synth_dataset_exp$experiment model=synth_model_exp$experiment experiment=$experiment
# Out:
# ^C

# %%
# !ssrun --multirun dataset=synth_dataset_exp$experiment model=synth_model_exp$experiment experiment=$experiment dataset.gen.seed=range(1,6) model.cdl.interpolate=0,10 output.verbose=0 output.plot=1
# Out:
# [2024-01-05 18:17:55,338][HYDRA] Launching 2 jobs locally
# [2024-01-05 18:17:55,339][HYDRA] 	#0 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=1 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:18:14,760][HYDRA] 	#1 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=1 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 1268.18it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2754.58it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 1474.10it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\outputs\plot.py:141: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10,5))
# [2024-01-05 18:17:30,220][HYDRA] Launching 20 jobs locally
# [2024-01-05 18:17:30,220][HYDRA] 	#0 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=1 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:17:47,834][HYDRA] 	#1 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=1 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:17:51,546][HYDRA] 	#2 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=2 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:18:09,159][HYDRA] 	#3 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=2 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:18:12,610][HYDRA] 	#4 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=3 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:18:30,217][HYDRA] 	#5 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=3 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:18:33,916][HYDRA] 	#6 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=4 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:18:49,551][HYDRA] 	#7 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=4 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:18:52,946][HYDRA] 	#8 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=5 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:19:08,610][HYDRA] 	#9 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=5 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:19:12,312][HYDRA] 	#10 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=6 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:19:27,949][HYDRA] 	#11 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=6 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:19:31,063][HYDRA] 	#12 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=7 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:19:46,581][HYDRA] 	#13 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=7 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:19:50,063][HYDRA] 	#14 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=8 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:20:06,412][HYDRA] 	#15 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=8 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:20:09,996][HYDRA] 	#16 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=9 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:20:25,643][HYDRA] 	#17 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=9 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:20:29,184][HYDRA] 	#18 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=10 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:20:45,824][HYDRA] 	#19 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=10 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 3044.50it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 3018.21it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 3027.65it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\outputs\plot.py:141: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10,5))
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 2895.29it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 173 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 184 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 22550.02it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 3003.08it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 173 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 190 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2997.36it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 3030.57it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 3052.62it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2995.93it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 1524.65it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 184 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 200 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2999.50it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 2973.28it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 184 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 201 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 176 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 176 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 22550.02it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 1480.87it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 3004.52it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 2999.50it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 3002.37it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 30051 larger than seg_size 30000
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 3107.66it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 1500.65it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 176 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 30051 larger than seg_size 30000
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 3008.11it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 3003.80it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2990.95it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 1501.36it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 190 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 176 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2935.82it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 2973.28it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2995.93it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 2558.54it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 1495.47it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 3008.11it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2995.93it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2998.07it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 3000.93it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 193 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 184 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2897.95it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 1497.07it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm

# %%
report_multi_run_results(experiment)
# Out:
# Averaged accuracy:
# interpolation        0         10
# unit
# 0              0.100000  0.105263
# 1              0.210526  0.222910
