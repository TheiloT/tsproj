# %%
from cdlgr.outputs.metrics import average_multi_run_perfs

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # First set of experiments

# %%
def report_multi_run_results(experiment):
    dataset="synth"
    # TODO: add plots and time
    return average_multi_run_perfs(dataset, experiment, metric="accuracy")

# %% [markdown]
# ## Experiment 1

# %%
experiment = 1

# %%
# !ssrun dataset=synth_dataset_exp$experiment model=synth_model_exp$experiment experiment=$experiment
# Out:
# experiment: 1
# output:
#   verbose: 2
#   plot: 2
#   preprocess:
#     plot_traces: false
#     plot_waveforms: false
#     plot_snrs: false
#   fp_threshold_ms: 15
# dataset:
#   type: synth
#   name: synthetic
#   recording: synthetic
#   uri: null
#   tstart_s: null
#   tstop_s: null
#   duration_s: null
#   tstart_test_s: null
#   tstop_test_s: null
#   channel: 0
#   detect_threshold: 5
#   preprocess: false
#   preprocess_params:
#     freq_min: null
#     freq_max: null
#   window:
#     split: true
#     window_size_s: 0.015
#   sources:
#     num: 2
#     length_ms: 10.5
#   gen:
#     seed: null
#     noise: 0.1
#     amps:
#     - 1
#     - 2
#     numOfEvents: 10
#     T: 3
#   fs: 10000
# model:
#   dictionary:
#     num_elements: 2
#     element_length_ms: 10.5
#     init_templates: signal
#   cdl:
#     num_iterations: 10
#     interpolate: 0
#     sparsity_tol: 1
#     sparsity_tol_test: 40
#     rel_amp_split_test: 0.6
#     error_tol: 0.01
#     interpolator_type: sinc
#
# Working directory : d:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\outputs\synth_experiments\experiment_1\simple\interp_2_0\seed_None
# Output directory  : d:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\outputs\synth_experiments\experiment_1\simple\interp_2_0\seed_None
# Generating data
#
# Generating 1/2 elementsevents [0.01110284 0.09642391 0.42608139 0.93851505 1.66520012 2.34562393
#  2.58244138 2.60433149 2.715112   2.87401878]
#
# Generating 2/2 elementsevents [0.00787124 1.2614226  1.30829323 1.5998008  1.82112928 2.12605325
#  2.18845964 2.40397572 2.45540308 2.7226697 ]
#
# Generating 2/2 elements (retry 1)
# Generating 1/2 elementsevents [0.15379438 0.24808368 0.89173885 1.03125335 1.35498332 1.68112722
#  1.96290603 2.01654822 2.26714799 2.57994011]
#
# Generating 2/2 elementsevents [0.57665447 0.72962943 1.18438143 1.47248157 1.48444229 1.87849754
#  1.92895533 2.44203316 2.58717302 2.96441738]
# Data generated
#
# Creating dictionary with 2 elements of length 105 samples (10.5 ms).
# Initializing dictionary...
# Setting 'return_scaled' to False
#
# Splitting traces...
# 	Retrieving traces...
# Creating dictionary with 2 elements of length 105 samples (10.5 ms).
# Creating dictionary with 2 elements of length 105 samples (10.5 ms).
# Preprocessing time:  0.4302767999470234
# Splitting done.
#
# Running CDL...
# Creating dictionary with 2 elements of length 105 samples (10.5 ms).
# Iteration 1/10
# Choice 6.485533588111925 0 127
# Choice 5.5507403044306285 1 127
# Choice 4.033159417975351 1 125
# Choice 3.691505933981108 0 126
# Choice 4.157222217963558 1 130
# Choice 2.433042427209621 1 127
# Choice 3.972047089327104 1 130
# Choice 3.122719392890174 1 128
# Choice 5.696801761103349 0 128
# Choice 2.5702935155223696 1 130
# Choice 3.5037351586329315 1 130
# Choice 3.5667431406289176 1 128
# Choice 3.7773258675477863 0 125
# Choice 3.391969103987451 1 130
# Choice 4.068515107960254 1 129
# Choice 6.236082537323166 0 125
# Choice 5.339238643934126 0 127
# Choice 6.251691398212385 0 128
# Choice 5.5407348417257545 0 52
# Choice 4.111724403205507 0 125
# Updating Filter 0
# Updating Filter 1
# Creating dictionary with 2 elements of length 105 samples (10.5 ms).
# Dictionary error (original and interpolated): [0.99300429 0.79617801] [0.04166446 0.18232216]
#
# Iteration 2/10
# Choice 6.422164788083507 0 127
# Choice 5.424461895964098 0 127
# Choice 4.071275013553717 0 125
# Choice 3.738955355999673 0 126
# Choice 7.87361893524812 1 130
# Choice 4.67093431155293 1 127
# Choice 7.592931141456388 1 130
# Choice 5.673949918017579 1 128
# Choice 5.751556154691653 0 128
# Choice 4.570423211412499 1 130
# Choice 6.457981487025363 1 130
# Choice 6.697651631145958 1 128
# Choice 3.84670401975227 0 125
# Choice 6.324868774327131 1 130
# Choice 7.562805481104475 1 129
# Choice 6.340778371312445 0 125
# Choice 5.425509469776109 0 127
# Choice 6.351159558147378 0 128
# Choice 5.6024369706158925 0 52
# Choice 4.149290661022703 0 125
# Updating Filter 0
# Updating Filter 1
# Creating dictionary with 2 elements of length 105 samples (10.5 ms).
# Dictionary error (original and interpolated): [0.99263862 0.75855333] [0.01724129 0.06988367]
#
# Iteration 3/10
# Choice 6.419711892331404 0 127
# Choice 5.453256121822492 0 127
# Choice 4.096897386073784 0 125
# Choice 3.7433027161301116 0 126
# Choice 8.006802028677761 1 130
# Choice 4.754084966842454 1 127
# Choice 7.729224190668624 1 130
# Choice 5.733374039638174 1 128
# Choice 5.749726475297513 0 128
# Choice 4.613815180799886 1 130
# Choice 6.5433739738053225 1 130
# Choice 6.807722318808775 1 128
# Choice 3.8437070281379273 0 125
# Choice 6.415965020202016 1 130
# Choice 7.668161553449442 1 129
# Choice 6.336026691598593 0 125
# Choice 5.418348250745831 0 127
# Choice 6.347226494109185 0 128
# Choice 5.601678942095967 0 52
# Choice 4.148554953530549 0 125
# Updating Filter 0
# Updating Filter 1
# Creating dictionary with 2 elements of length 105 samples (10.5 ms).
# Dictionary error (original and interpolated): [0.99263553 0.75855376] [0.01716534 0.06991671]
#
# Iteration 4/10
# Choice 6.419690193375247 0 127
# Choice 5.45338901531269 0 127
# Choice 4.097035963759812 0 125
# Choice 3.7433411988311227 0 126
# Choice 8.006824280429486 1 130
# Choice 4.7541261975910505 1 127
# Choice 7.729286374056864 1 130
# Choice 5.733329970053629 1 128
# Choice 5.749709662759159 0 128
# Choice 4.613743433266458 1 130
# Choice 6.543358447505271 1 130
# Choice 6.80776382376228 1 128
# Choice 3.8436743632752948 0 125
# Choice 6.415939928900535 1 130
# Choice 7.668123996013731 1 129
# Choice 6.335967896288365 0 125
# Choice 5.418267681611692 0 127
# Choice 6.347189732559778 0 128
# Choice 5.6016677755005695 0 52
# Choice 4.148548158631706 0 125
# Updating Filter 0
# Updating Filter 1
# Creating dictionary with 2 elements of length 105 samples (10.5 ms).
# Dictionary error (original and interpolated): [0.9926355  0.75855378] [0.01716487 0.06991684]
#
# Iteration 5/10
# Choice 6.419690124439972 0 127
# Choice 5.45338973262087 0 127
# Choice 4.097036801131371 0 125
# Choice 3.7433415220307498 0 126
# Choice 8.00682428688284 1 130
# Choice 4.754126349030583 1 127
# Choice 7.7292865697692985 1 130
# Choice 5.733329886343131 1 128
# Choice 5.749709634494826 0 128
# Choice 4.613743227445095 1 130
# Choice 6.543358450912701 1 130
# Choice 6.807763994482999 1 128
# Choice 3.8436741489342983 0 125
# Choice 6.415939799097876 1 130
# Choice 7.6681238386748785 1 129
# Choice 6.335967451933894 0 125
# Choice 5.418267074433606 0 127
# Choice 6.3471895663197495 0 128
# Choice 5.601667743557614 0 52
# Choice 4.148548167585791 0 125
# Updating Filter 0
# Updating Filter 1
# Creating dictionary with 2 elements of length 105 samples (10.5 ms).
# Dictionary error (original and interpolated): [0.9926355  0.75855378] [0.01716486 0.06991684]
#
# Iteration 6/10
# Choice 6.419690124342587 0 127
# Choice 5.453389736671976 0 127
# Choice 4.0970368063291005 0 125
# Choice 3.743341524383501 0 126
# Choice 8.006824286705342 1 130
# Choice 4.754126349637769 1 127
# Choice 7.729286570445474 1 130
# Choice 5.733329886133466 1 128
# Choice 5.749709634785746 0 128
# Choice 4.613743226851019 1 130
# Choice 6.543358451077747 1 130
# Choice 6.807763995204872 1 128
# Choice 3.8436741475191485 0 125
# Choice 6.415939798496871 1 130
# Choice 7.668123838037556 1 129
# Choice 6.335967448590289 0 125
# Choice 5.418267070021634 0 127
# Choice 6.34718956569916 0 128
# Choice 5.601667743609537 0 52
# Choice 4.148548167881398 0 125
# Updating Filter 0
# Updating Filter 1
# Creating dictionary with 2 elements of length 105 samples (10.5 ms).
# Dictionary error (original and interpolated): [0.9926355  0.75855378] [0.01716486 0.06991684]
#
# Iteration 7/10
# Choice 6.41969012434372 0 127
# Choice 5.453389736695701 0 127
# Choice 4.097036806362165 0 125
# Choice 3.7433415243997943 0 126
# Choice 8.006824286704047 1 130
# Choice 4.754126349640303 1 127
# Choice 7.729286570447963 1 130
# Choice 5.733329886132693 1 128
# Choice 5.74970963479043 0 128
# Choice 4.613743226849296 1 130
# Choice 6.543358451078796 1 130
# Choice 6.807763995208009 1 128
# Choice 3.843674147509724 0 125
# Choice 6.415939798494218 1 130
# Choice 7.668123838034986 1 129
# Choice 6.335967448565434 0 125
# Choice 5.41826706999016 0 127
# Choice 6.347189565697867 0 128
# Choice 5.6016677436114595 0 52
# Choice 4.148548167884382 0 125
# Updating Filter 0
# Updating Filter 1
# Creating dictionary with 2 elements of length 105 samples (10.5 ms).
# Dictionary error (original and interpolated): [0.9926355  0.75855378] [0.01716486 0.06991684]
#
# Iteration 8/10
# Choice 6.419690124343736 0 127
# Choice 5.453389736695845 0 127
# Choice 4.097036806362379 0 125
# Choice 3.7433415243999066 0 126
# Choice 8.006824286704038 1 130
# Choice 4.754126349640314 1 127
# Choice 7.729286570447972 1 130
# Choice 5.733329886132691 1 128
# Choice 5.749709634790479 0 128
# Choice 4.613743226849292 1 130
# Choice 6.5433584510788005 1 130
# Choice 6.807763995208021 1 128
# Choice 3.843674147509661 0 125
# Choice 6.415939798494207 1 130
# Choice 7.668123838034976 1 129
# Choice 6.335967448565252 0 125
# Choice 5.4182670699899385 0 127
# Choice 6.347189565697875 0 128
# Choice 5.60166774361148 0 52
# Choice 4.148548167884407 0 125
# Updating Filter 0
# Updating Filter 1
# Creating dictionary with 2 elements of length 105 samples (10.5 ms).
# Dictionary error (original and interpolated): [0.9926355  0.75855378] [0.01716486 0.06991684]
#
# Iteration 9/10
# Choice 6.419690124343735 0 127
# Choice 5.453389736695845 0 127
# Choice 4.0970368063623805 0 125
# Choice 3.7433415243999066 0 126
# Choice 8.006824286704038 1 130
# Choice 4.754126349640315 1 127
# Choice 7.729286570447973 1 130
# Choice 5.733329886132692 1 128
# Choice 5.749709634790477 0 128
# Choice 4.6137432268492935 1 130
# Choice 6.5433584510788005 1 130
# Choice 6.807763995208023 1 128
# Choice 3.8436741475096596 0 125
# Choice 6.4159397984942075 1 130
# Choice 7.668123838034976 1 129
# Choice 6.335967448565249 0 125
# Choice 5.418267069989935 0 127
# Choice 6.3471895656978745 0 128
# Choice 5.601667743611482 0 52
# Choice 4.148548167884406 0 125
# Updating Filter 0
# Updating Filter 1
# Creating dictionary with 2 elements of length 105 samples (10.5 ms).
# Dictionary error (original and interpolated): [0.9926355  0.75855378] [0.01716486 0.06991684]
#
# Iteration 10/10
# Choice 6.4196901243437345 0 127
# Choice 5.453389736695845 0 127
# Choice 4.09703680636238 0 125
# Choice 3.743341524399906 0 126
# Choice 8.006824286704038 1 130
# Choice 4.754126349640314 1 127
# Choice 7.729286570447972 1 130
# Choice 5.733329886132691 1 128
# Choice 5.749709634790478 0 128
# Choice 4.613743226849292 1 130
# Choice 6.5433584510788005 1 130
# Choice 6.807763995208022 1 128
# Choice 3.8436741475096596 0 125
# Choice 6.4159397984942075 1 130
# Choice 7.668123838034976 1 129
# Choice 6.335967448565249 0 125
# Choice 5.418267069989935 0 127
# Choice 6.3471895656978745 0 128
# Choice 5.601667743611483 0 52
# Choice 4.148548167884406 0 125
# Creating dictionary with 2 elements of length 105 samples (10.5 ms).
# Dictionary error (original and interpolated): [0.9926355  0.75855378] [0.01716486 0.06991684]
#
# Total time:  5.870922699919902
# CSC time:  0.336653400096111
# Update time:  0.4481260001193732
#
# Groundtruth     sample_index  unit_index  segment_index
# 0            163           0              0
# 1           1016           0              0
# 2           4313           0              0
# 3           9437           0              0
# 4          12666           1              0
# 5          13135           1              0
# 6          13330           1              0
# 7          16050           1              0
# 8          16704           0              0
# 9          18263           1              0
# 10         21313           1              0
# 11         21937           1              0
# 12         23508           0              0
# 13         24092           1              0
# 14         24606           1              0
# 15         25876           0              0
# 16         26095           0              0
# 17         27203           0              0
# 18         27279           1              0
# 19         28792           0              0
#
# Not reconstructing segment 10/20
# Not reconstructing segment 11/20
# Not reconstructing segment 12/20
# Not reconstructing segment 13/20
# Not reconstructing segment 14/20
# Not reconstructing segment 15/20
# Not reconstructing segment 16/20
# Not reconstructing segment 17/20
# Not reconstructing segment 18/20
# Not reconstructing segment 19/20
#     sample_index  unit_index  amplitude  error
# 3         9433.0         0.0   3.743342    0.0
# 12       23505.0         0.0   3.843674    0.0
# 2         4310.0         0.0   4.097037    0.0
# 19       28789.0         0.0   4.148548    0.0
# 9        18255.0         1.0   4.613743    0.0
# 5        13129.0         1.0   4.754126    0.0
# 16       26090.0         0.0   5.418267    0.0
# 1         1011.0         0.0   5.453390    0.0
# 18       27273.0         0.0   5.601668    0.0
# 7        16044.0         1.0   5.733330    0.0
# 8        16698.0         0.0   5.749710    0.0
# 15       25873.0         0.0   6.335967    0.0
# 17       27197.0         0.0   6.347190    0.0
# 13       24084.0         1.0   6.415940    0.0
# 0          158.0         0.0   6.419690    0.0
# 10       21304.0         1.0   6.543358    0.0
# 11       21930.0         1.0   6.807764    0.0
# 14       24599.0         1.0   7.668124    0.0
# 6        13322.0         1.0   7.729287    0.0
# 4        12658.0         1.0   8.006824    0.0
# Mode split
# [(  158, 0, 0) ( 1011, 0, 0) ( 4310, 0, 0) ( 9433, 0, 0) (12658, 1, 0)
#  (13129, 1, 0) (13322, 1, 0) (16044, 1, 0) (16698, 0, 0) (18255, 1, 0)
#  (21304, 1, 0) (21930, 1, 0) (23505, 0, 0) (24084, 1, 0) (24599, 1, 0)
#  (25873, 0, 0) (26090, 0, 0) (27197, 0, 0) (27273, 0, 0) (28789, 0, 0)]
# Confusion matrix:
#     0.0  1.0  FN
# 0    10    0   0
# 1     0    9   1
# FP    1    0   0
#
# SUMMARY
# -------
# GT num_units: 2
# TESTED num_units: 2
# num_well_detected: 2
# num_redundant: 0
# num_overmerged: 0
# num_false_positive_units 0
# num_bad: 0
#
# PERFORMANCE (pooled_with_average)
# -----------
# ACCURACY: 90.45454545454545
# RECALL: 95.0
# PRECISION: 95.45454545454545
# FALSE DISCOVERY RATE: 4.545454545454546
# MISS RATE: 5.0
#
#
# Finding good detections and false positives...
# TP spike found.
# FP spike found.
#
#
# ==============
# Testing...
# Choice 8.006824286704038 1 12713
# Choice 7.729286570447972 1 13377
# Choice 7.668123838034976 1 24653
# Choice 6.807763995208022 1 21983
# Choice 6.5433584510788005 1 21359
# Choice 6.4196901243437345 0 210
# Choice 6.4159397984942075 1 24139
# Choice 6.3471895656978745 0 27250
# Choice 6.335967448565249 0 25923
# Choice 5.749709634790478 0 16751
# Choice 5.733329886132691 1 16097
# Choice 5.453389736695845 0 1063
# Choice 5.418267069989935 0 26142
# Choice 4.754126349640314 1 13181
# Choice 4.613743226849292 1 18310
# Choice 4.397805655895233 1 27325
# Choice 4.148548167884406 0 28839
# Choice 4.09703680636238 0 4360
# Choice 3.8436741475096596 0 23555
# Choice 3.743341524399906 0 9484
# Choice 0.47737524496423117 0 25928
# Choice 0.44180868034013926 1 13190
# Choice 0.4225898153508862 1 7453
# Choice 0.3806678646703244 1 26863
# Choice 0.38014567421457357 0 24145
# Choice 0.37526200781578894 0 28664
# Choice 0.37129883700139515 1 3962
# Choice 0.36763991041328453 0 23383
# Choice 0.3636556752470079 0 1945
# Choice 0.3602857519628484 0 24255
# Choice 0.35684181434995016 1 7483
# Choice 0.35349162948867274 0 22883
# Choice 0.3517224440831666 1 13607
# Choice 0.3508622531108488 0 29483
# Choice 0.34843544539151067 1 19130
# Choice 0.34521186694030576 0 1243
# Choice 0.34088311020235473 1 10913
# Choice 0.3405408553972325 0 21870
# Choice 0.34037006312623425 1 12117
# Choice 0.3393386838186529 1 8779
# Groundtruth     sample_index  unit_index  segment_index
# 0            163           0              0
# 1           1016           0              0
# 2           4313           0              0
# 3           9437           0              0
# 4          12666           1              0
# 5          13135           1              0
# 6          13330           1              0
# 7          16050           1              0
# 8          16704           0              0
# 9          18263           1              0
# 10         21313           1              0
# 11         21937           1              0
# 12         23508           0              0
# 13         24092           1              0
# 14         24606           1              0
# 15         25876           0              0
# 16         26095           0              0
# 17         27203           0              0
# 18         27279           1              0
# 19         28792           0              0
#
#     sample_index  unit_index  amplitude     error
# 5         9432.0         0.0   3.743342  0.447664
# 10       23503.0         0.0   3.843674  0.468575
# 4         4308.0         0.0   4.097037  0.423016
# 18       28787.0         0.0   4.148548  0.441196
# 39       27273.0         1.0   4.397806  0.357151
# 32       18258.0         1.0   4.613743  0.361594
# 27       13129.0         1.0   4.671434  0.345373
# 15       26090.0         0.0   5.418267  0.428352
# 1         1011.0         0.0   5.453390  0.396639
# 31       16045.0         1.0   5.733330  0.262847
# 6        16699.0         0.0   5.749710  0.334652
# 13       25871.0         0.0   6.277271  0.377781
# 16       27198.0         0.0   6.348037  0.293213
# 0          158.0         0.0   6.419690  0.338153
# 36       24087.0         1.0   6.442760  0.250146
# 34       21307.0         1.0   6.543358  0.286928
# 35       21931.0         1.0   6.807764  0.289935
# 37       24601.0         1.0   7.668124  0.243122
# 29       13325.0         1.0   7.729287  0.228798
# 26       12661.0         1.0   8.006824  0.251554
# Mode whole
#     sample_index  unit_index  amplitude     error      diff
# 11       24093.0         0.0  -0.382029  0.249597 -0.000000
# 9        23331.0         0.0  -0.367640  0.970411 -0.039138
# 3         1893.0         0.0  -0.363656  0.964785 -0.010956
# 12       24203.0         0.0  -0.360286  0.964137 -0.009353
# 19       29431.0         0.0  -0.350862  0.975004 -0.026858
# 2         1191.0         0.0  -0.345212  0.973289 -0.016368
# 7        21818.0         0.0   0.340541  0.284048  2.013716
# 8        22831.0         0.0   0.353492  0.973804  0.036637
# 17       28612.0         0.0   0.375262  0.966940  0.058014
# 14       25876.0         0.0   0.484486  0.376979  0.225444
# 5         9432.0         0.0   3.743342  0.447664  0.870574
# 10       23503.0         0.0   3.843674  0.468575  0.026103
# 4         4308.0         0.0   4.097037  0.423016  0.061840
# 18       28787.0         0.0   4.148548  0.441196  0.012417
# 15       26090.0         0.0   5.418267  0.428352  0.234340
# 1         1011.0         0.0   5.453390  0.396639  0.006441
# 6        16699.0         0.0   5.749710  0.334652  0.051536
# 13       25871.0         0.0   6.277271  0.377781  0.084043
# 16       27198.0         0.0   6.348037  0.293213  0.011148
# 0          158.0         0.0   6.419690  0.338153  0.011161
#     sample_index  unit_index  amplitude     error      diff
# 24       10861.0         1.0  -0.340883  0.974486 -0.000000
# 25       12065.0         1.0  -0.340370  0.972413 -0.001507
# 23        8727.0         1.0   0.339339  0.977725  2.003039
# 33       19078.0         1.0   0.348435  0.969890  0.026107
# 30       13555.0         1.0   0.351722  0.974890  0.009345
# 22        7431.0         1.0   0.361636  0.926240  0.027414
# 20        3910.0         1.0   0.371299  0.968170  0.026023
# 38       26811.0         1.0   0.380668  0.967004  0.024612
# 28       13138.0         1.0   0.456779  0.347607  0.166625
# 21        7401.0         1.0   0.464230  0.929513  0.016051
# 39       27273.0         1.0   4.397806  0.357151  0.894440
# 32       18258.0         1.0   4.613743  0.361594  0.046803
# 27       13129.0         1.0   4.671434  0.345373  0.012350
# 31       16045.0         1.0   5.733330  0.262847  0.185215
# 36       24087.0         1.0   6.442760  0.250146  0.110113
# 34       21307.0         1.0   6.543358  0.286928  0.015374
# 35       21931.0         1.0   6.807764  0.289935  0.038839
# 37       24601.0         1.0   7.668124  0.243122  0.112200
# 29       13325.0         1.0   7.729287  0.228798  0.007913
# 26       12661.0         1.0   8.006824  0.251554  0.034663
#     sample_index  unit_index  amplitude     error
# 11       24093.0         0.0  -0.382029  0.249597
# 9        23331.0         0.0  -0.367640  0.970411
# 3         1893.0         0.0  -0.363656  0.964785
# 12       24203.0         0.0  -0.360286  0.964137
# 19       29431.0         0.0  -0.350862  0.975004
# 2         1191.0         0.0  -0.345212  0.973289
# 24       10861.0         1.0  -0.340883  0.974486
# 25       12065.0         1.0  -0.340370  0.972413
# 23        8727.0         1.0   0.339339  0.977725
# 7        21818.0         0.0   0.340541  0.284048
# 33       19078.0         1.0   0.348435  0.969890
# 30       13555.0         1.0   0.351722  0.974890
# 8        22831.0         0.0   0.353492  0.973804
# 22        7431.0         1.0   0.361636  0.926240
# 20        3910.0         1.0   0.371299  0.968170
# 17       28612.0         0.0   0.375262  0.966940
# 38       26811.0         1.0   0.380668  0.967004
# 28       13138.0         1.0   0.456779  0.347607
# 21        7401.0         1.0   0.464230  0.929513
# 14       25876.0         0.0   0.484486  0.376979
# 5         9432.0         0.0   3.743342  0.447664
# 10       23503.0         0.0   3.843674  0.468575
# 4         4308.0         0.0   4.097037  0.423016
# 18       28787.0         0.0   4.148548  0.441196
# 39       27273.0         1.0   4.397806  0.357151
# 32       18258.0         1.0   4.613743  0.361594
# 27       13129.0         1.0   4.671434  0.345373
# 15       26090.0         0.0   5.418267  0.428352
# 1         1011.0         0.0   5.453390  0.396639
# 31       16045.0         1.0   5.733330  0.262847
# 6        16699.0         0.0   5.749710  0.334652
# 13       25871.0         0.0   6.277271  0.377781
# 16       27198.0         0.0   6.348037  0.293213
# 0          158.0         0.0   6.419690  0.338153
# 36       24087.0         1.0   6.442760  0.250146
# 34       21307.0         1.0   6.543358  0.286928
# 35       21931.0         1.0   6.807764  0.289935
# 37       24601.0         1.0   7.668124  0.243122
# 29       13325.0         1.0   7.729287  0.228798
# 26       12661.0         1.0   8.006824  0.251554
# [(  158, 0, 0) ( 1011, 0, 0) ( 4308, 0, 0) ( 9432, 0, 0) (12661, 1, 0)
#  (13129, 1, 0) (13325, 1, 0) (16045, 1, 0) (16699, 0, 0) (18258, 1, 0)
#  (21307, 1, 0) (21931, 1, 0) (23503, 0, 0) (24087, 1, 0) (24601, 1, 0)
#  (25871, 0, 0) (26090, 0, 0) (27198, 0, 0) (27273, 1, 0) (28787, 0, 0)]
# Confusion matrix:
#     0.0  1.0  FN
# 0    10    0   0
# 1     0   10   0
# FP    0    0   0
#
# SUMMARY
# -------
# GT num_units: 2
# TESTED num_units: 2
# num_well_detected: 2
# num_redundant: 0
# num_overmerged: 0
# num_false_positive_units 0
# num_bad: 0
#
# PERFORMANCE (pooled_with_average)
# -----------
# ACCURACY: 100.0
# RECALL: 100.0
# PRECISION: 100.0
# FALSE DISCOVERY RATE: 0.0
# MISS RATE: 0.0
#
#
# Finding good detections and false positives...
# TP spike found.
# FP spike found.
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2996.64it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# 0it [00:00, ?it/s]
# 20it [00:00, 981.89it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:00<00:00, 562.25it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:00<00:00, 656.25it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:00<00:00, 636.56it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:00<00:00, 576.20it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\outputs\plot.py:126: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10,5))
#
#   0%|          | 0/20 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:00<00:00, 655.19it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:00<00:00, 634.51it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:00<00:00, 521.92it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:00<00:00, 651.00it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:00<00:00, 621.29it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:00<00:00, 638.06it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:437: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(labels=ax1.get_xticklabels(), rotation=45)
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:437: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(labels=ax1.get_xticklabels(), rotation=45)

# %%
# !ssrun --multirun dataset=synth_dataset_exp$experiment model=synth_model_exp$experiment experiment=$experiment dataset.gen.seed=range(1,6) model.cdl.interpolate=0,10 output.verbose=0 output.plot=1
# Out:
# [2024-01-05 18:17:55,338][HYDRA] Launching 2 jobs locally
# [2024-01-05 18:17:55,339][HYDRA] 	#0 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=1 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:18:14,760][HYDRA] 	#1 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=1 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 1268.18it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2754.58it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 1474.10it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\outputs\plot.py:141: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10,5))
# [2024-01-05 18:17:30,220][HYDRA] Launching 20 jobs locally
# [2024-01-05 18:17:30,220][HYDRA] 	#0 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=1 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:17:47,834][HYDRA] 	#1 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=1 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:17:51,546][HYDRA] 	#2 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=2 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:18:09,159][HYDRA] 	#3 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=2 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:18:12,610][HYDRA] 	#4 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=3 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:18:30,217][HYDRA] 	#5 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=3 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:18:33,916][HYDRA] 	#6 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=4 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:18:49,551][HYDRA] 	#7 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=4 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:18:52,946][HYDRA] 	#8 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=5 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:19:08,610][HYDRA] 	#9 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=5 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:19:12,312][HYDRA] 	#10 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=6 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:19:27,949][HYDRA] 	#11 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=6 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:19:31,063][HYDRA] 	#12 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=7 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:19:46,581][HYDRA] 	#13 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=7 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:19:50,063][HYDRA] 	#14 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=8 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:20:06,412][HYDRA] 	#15 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=8 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:20:09,996][HYDRA] 	#16 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=9 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:20:25,643][HYDRA] 	#17 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=9 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# [2024-01-05 18:20:29,184][HYDRA] 	#18 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=10 model.cdl.interpolate=10 output.verbose=0 output.plot=1
# ===============
# 10
# Setting 'return_scaled' to False
# [2024-01-05 18:20:45,824][HYDRA] 	#19 : dataset=synth_dataset_exp1 model=synth_model_exp1 experiment=1 dataset.gen.seed=10 model.cdl.interpolate=0 output.verbose=0 output.plot=1
# ===============
# 0
# Setting 'return_scaled' to False
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 3044.50it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 3018.21it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 3027.65it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\outputs\plot.py:141: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10,5))
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 2895.29it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 173 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 184 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 22550.02it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 3003.08it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 173 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 190 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2997.36it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 3030.57it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 3052.62it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2995.93it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 1524.65it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 184 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 200 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2999.50it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 2973.28it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 184 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 201 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 176 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 176 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 22550.02it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 1480.87it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 3004.52it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 2999.50it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 3002.37it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 30051 larger than seg_size 30000
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 3107.66it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 1500.65it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 176 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 30051 larger than seg_size 30000
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 3008.11it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 3003.80it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2990.95it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 1501.36it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 190 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 176 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2935.82it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 2973.28it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2995.93it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 2558.54it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 1495.47it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 3008.11it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2995.93it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2998.07it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 3000.93it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 193 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 184 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<?, ?it/s]
#
# extract waveforms shared_memory multi buffer:   0%|          | 0/3 [00:00<?, ?it/s]
# extract waveforms shared_memory multi buffer: 100%|##########| 3/3 [00:00<00:00, 2897.95it/s]
#
# detect peaks using by_channel:   0%|          | 0/3 [00:00<?, ?it/s]
# detect peaks using by_channel: 100%|##########| 3/3 [00:00<00:00, 1497.07it/s]
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 189 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 185 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 188 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 187 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 175 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 186 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:286: UserWarning: idx 174 larger than seg_size 150
#   warnings.warn(f"idx {firing_idx} larger than seg_size {seg_size}")
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm
# D:\Etudes\Ponts et chaussees\MVA\Cours\AST\tsproj\cdlgr\model\cdl.py:350: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_spike_sorting["diff"] = diffs_norm

# %%
report_multi_run_results(experiment)
# Out:
# Averaged accuracy:
# interpolation        0         10
# unit
# 0              0.100000  0.105263
# 1              0.210526  0.222910
